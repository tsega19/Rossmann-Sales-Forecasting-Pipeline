# %%
import os
import sys
import pandas as pd
sys.path.append(os.path.abspath('../scripts'))
from data_preprocessing import *
from feature_Engineering import create_features, plot_feature_distributions

# %%
test_data = pd.read_csv('../data/processed_data_test.csv')

# %%
create_features(test_data)
# Out:
# Starting feature engineering...
# Starting feature engineering...
# Date-related features extracted.
# Date-related features extracted.
# Feature engineering completed.
# Feature engineering completed.
#           Id  Store  DayOfWeek       Date  Open  Promo StateHoliday  \
# 0          1      1          3 2015-09-17   1.0      1            0
# 1          2      3          3 2015-09-17   1.0      1            0
# 2          3      7          3 2015-09-17   1.0      1            0
# 3          4      8          3 2015-09-17   1.0      1            0
# 4          5      9          3 2015-09-17   1.0      1            0
# ...      ...    ...        ...        ...   ...    ...          ...
# 41083  41084   1111          5 2015-08-01   1.0      0            0
# 41084  41085   1112          5 2015-08-01   1.0      0            0
# 41085  41086   1113          5 2015-08-01   1.0      0            0
# 41086  41087   1114          5 2015-08-01   1.0      0            0
# ...

# %%
plot_feature_distributions(test_data)
# Out:
# Feature 'Sales' not found in the dataset.
# Feature 'Sales' not found in the dataset.
# Feature 'LogSales' not found in the dataset.
# Feature 'LogSales' not found in the dataset.
# Feature 'PromoImpact' not found in the dataset.
# Feature 'PromoImpact' not found in the dataset.
# Feature 'CompetitionProximity' not found in the dataset.
# Feature 'CompetitionProximity' not found in the dataset.
# c:\Users\Tsega KisPay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Plotting distribution of 'IsChristmas'.
# Plotting distribution of 'IsChristmas'.
# c:\Users\Tsega KisPay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
# Assume 'processed_data' is your preprocessed DataFrame
test_data.to_csv('../data/test_data_feature.csv', index=False)
print("Preprocessed data saved to '../data/test_data_feature.csv'")
# Out:
# Preprocessed data saved to '../data/test_data_feature.csv'
