# %%
import os
import sys
import pandas as pd
sys.path.append(os.path.abspath('../scripts'))
from data_preprocessing import *
from feature_Engineering import create_features, plot_feature_distributions

# %%
test_data = pd.read_csv('../data/raw/4_test.csv')

# %%
clean_data(test_data)
# Out:
# Starting data cleaning...
# c:\Users\Tsega KisPay\Documents\GitHub\Rossmann-Sales-Forecasting-Pipeline\scripts\data_preprocessing.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].median(), inplace=True)
# Filled 11 missing values in Open with median.
# Detected 0 outliers in Id.
# Detected 0 outliers in Store.
# Detected 0 outliers in DayOfWeek.
# Detected 5984 outliers in Open.
# Detected 0 outliers in Promo.
# Detected 0 outliers in SchoolHoliday.
# Data cleaning completed.
# ...

# %%
visualize_data(test_data)
# Out:
# Starting data visualization...
# c:\Users\Tsega KisPay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Tsega KisPay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Tsega KisPay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
check_promotions_distribution(test_data)
# Out:
# Checking distribution of promotions between training and test sets...
# Promo distribution:
# Promo
# 0    24824
# 1    16264
# dtype: int64

# %%
# Assume 'processed_data' is your preprocessed DataFrame
test_data.to_csv('../data/processed_data_test.csv', index=False)
print("Preprocessed data saved to '../data/processed_data_test.csv'")
# Out:
# Preprocessed data saved to '../data/processed_data_test.csv'
