# %%
import os
import sys
import pandas as pd
sys.path.append(os.path.abspath('../scripts'))
from feature_Engineering import create_features, plot_feature_distributions

# %%
train_data = pd.read_csv('../data/raw/4_train.csv')
test_data = pd.read_csv('../data/raw/4_test.csv')
store_data = pd.read_csv('../data/raw/4_store.csv')
# Out:
# C:\Users\Tsega KisPay\AppData\Local\Temp\ipykernel_21536\2712326161.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_data = pd.read_csv('../data/raw/4_train.csv')

# %%
create_features(train_data)
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          4 2015-07-31   5263        555     1      1
# 1            2          4 2015-07-31   6064        625     1      1
# 2            3          4 2015-07-31   8314        821     1      1
# 3            4          4 2015-07-31  13995       1498     1      1
# 4            5          4 2015-07-31   4822        559     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017204   1111          1 2013-01-01      0          0     0      0
# 1017205   1112          1 2013-01-01      0          0     0      0
# 1017206   1113          1 2013-01-01      0          0     0      0
# 1017207   1114          1 2013-01-01      0          0     0      0
# 1017208   1115          1 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday  Year  Month  Day  WeekOfYear  IsWeekend  \
# 0                  0              1  2015      7   31          31          0
# 1                  0              1  2015      7   31          31          0
# 2                  0              1  2015      7   31          31          0
# 3                  0              1  2015      7   31          31          0
# 4                  0              1  2015      7   31          31          0
# ...              ...            ...   ...    ...  ...         ...        ...
# 1017204            a              1  2013      1    1           1          0
# 1017205            a              1  2013      1    1           1          0
# 1017206            a              1  2013      1    1           1          0
# 1017207            a              1  2013      1    1           1          0
# 1017208            a              1  2013      1    1           1          0
#
#          IsChristmas  IsEaster  PromoImpact  LogSales
# 0                  0         0          555  8.568646
# 1                  0         0          625  8.710290
# 2                  0         0          821  9.025816
# 3                  0         0         1498  9.546527
# 4                  0         0          559  8.481151
# ...              ...       ...          ...       ...
# 1017204            0         0            0  0.000000
# 1017205            0         0            0  0.000000
# 1017206            0         0            0  0.000000
# 1017207            0         0            0  0.000000
# 1017208            0         0            0  0.000000
#
# [1017209 rows x 18 columns]

# %%
plot_feature_distributions(train_data)
# Out:
# c:\Users\Tsega KisPay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Tsega KisPay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Tsega KisPay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Tsega KisPay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Tsega KisPay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
