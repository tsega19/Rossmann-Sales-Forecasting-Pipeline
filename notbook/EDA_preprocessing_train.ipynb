# %%
import os
import sys
import pandas as pd
sys.path.append(os.path.abspath('../scripts'))
from data_preprocessing import *
from feature_Engineering import create_features, plot_feature_distributions

# %%
train_data = pd.read_csv('../data/raw/4_train.csv')
test_data = pd.read_csv('../data/raw/4_test.csv')
store_data = pd.read_csv('../data/raw/4_store.csv')
# Out:
# C:\Users\Tsega KisPay\AppData\Local\Temp\ipykernel_2496\2712326161.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_data = pd.read_csv('../data/raw/4_train.csv')

# %%
clean_data(train_data)
# Out:
# Starting data cleaning...
# Detected 0 outliers in Store.
# Detected 0 outliers in DayOfWeek.
# Detected 26694 outliers in Sales.
# Detected 38095 outliers in Customers.
# Detected 172817 outliers in Open.
# Detected 0 outliers in Promo.
# Detected 181721 outliers in SchoolHoliday.
# Data cleaning completed.
#          Store  DayOfWeek        Date    Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263.0        555     1      1
# 1            2          5  2015-07-31   6064.0        625     1      1
# 2            3          5  2015-07-31   8314.0        821     1      1
# 3            4          5  2015-07-31  13995.0       1485     1      1
# 4            5          5  2015-07-31   4822.0        559     1      1
# ...        ...        ...         ...      ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0.0          0     1      0
# 1017205   1112          2  2013-01-01      0.0          0     1      0
# ...

# %%
visualize_data(train_data)
# Out:
# Starting data visualization...
# c:\Users\Tsega KisPay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Tsega KisPay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Tsega KisPay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
check_promotions_distribution(train_data)
# Out:
# Checking distribution of promotions between training and test sets...
# Promo distribution:
# Promo
# 0    629129
# 1    388080
# dtype: int64

# %%
analyze_sales_behavior(train_data)
# Out:
# Analyzing sales behavior around holidays...
# Average sales before holiday: 5862.657645977981
# Average sales during holiday: 232.94243156199678
# c:\Users\Tsega KisPay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
seasonal_purchase_behavior(train_data)
# Out:
# Checking seasonal purchase behavior...
# Seasonal sales by holiday:
# StateHoliday
# 0    5671.528473
# 0    5891.954879
# a     266.167053
# b     181.978700
# c     151.922073
# Name: Sales, dtype: float64

# %%
sales_and_customers_correlation(train_data)
# Out:
# Analyzing correlation between sales and number of customers...
# Correlation between sales and customers: 0.920804853199652

# %%
promo_effect_on_sales(train_data)
# Out:
# Analyzing the effect of promotions on sales...
# Average sales with and without promotions:
# Promo
# 0    4367.538696
# 1    7836.013738
# Name: Sales, dtype: float64

# %%
analyze_customer_behavior(train_data)
# Out:
# Analyzing customer behavior during store operating hours...
# Average sales for open stores: 5690.812275550059
# Average sales for closed stores: nan
# c:\Users\Tsega KisPay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
store_open_weekdays(train_data)
# Out:
# Checking store operations on weekdays and sales on weekends...
# Stores open weekdays and weekend sales:
# Store
# 1        3945.704883
# 2        4122.991507
# 3        5737.905520
# 4        7986.484076
# 5        3867.110403
#             ...
# 1111     4342.968153
# 1112     8167.910297
# 1113     5513.815287
# 1114    11670.911359
# 1115     5225.296178
# Name: Sales, Length: 1115, dtype: float64

# %%
# Assume 'processed_data' is your preprocessed DataFrame
train_data.to_csv('../data/processed_data_train.csv', index=False)
print("Preprocessed data saved to '../data/processed_data_train.csv'")
# Out:
# Preprocessed data saved to '../data/processed_data_train.csv'
